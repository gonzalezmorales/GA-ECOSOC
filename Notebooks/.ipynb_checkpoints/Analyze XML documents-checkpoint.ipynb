# %%
# import xml.dom.minidom as minidom
import os
import pandas as pd
from natsort import os_sorted
from markdownify import markdownify as md
import xml.etree.ElementTree as ET
import copy

import warnings
warnings.filterwarnings('ignore')

# %%
def get_coverPage_data(akn, coverPage):

    coverPage_data = dict()
    coverPage_data['publisher'] = coverPage.find(".//"+akn+"docAuthority[@refersTo='#publisher']").text
    coverPage_data['issuingBody'] = coverPage.find(".//"+akn+"docAuthority[@refersTo='#issuingBody']").text
    coverPage_data['symbol'] = coverPage.find(".//"+akn+"docNumber[@refersTo='#symbol']").text
    coverPage_data['docStatus'] = coverPage.find(".//"+akn+"docStatus").text
    coverPage_data['date'] = coverPage.find(".//"+akn+"docDate").attrib['date']
    coverPage_data['session'] = coverPage.find(".//"+akn+"session").attrib['value']
    coverPage_data['agendaItem'] = coverPage.find(".//"+akn+"inline[@name='agenda item']").text
    agendaItemDesc =  coverPage.find(".//"+akn+"inline[@name='agenda item name']")
    if(isinstance(agendaItemDesc, ET.Element)):
        agendaItemDesc = agendaItemDesc.text
    else: 
        agendaItemDesc = ''
    coverPage_data['agendaItemDesc'] =  agendaItemDesc   
    coverPage_data['docTitle'] = coverPage.find(".//"+akn+"docTitle").text

    return coverPage_data

# %%
def get_resolution_data(path,file, keywords):
    
    

    tree = ET.parse(path + file)
    root = tree.getroot()

    akn = "{http://docs.oasis-open.org/legaldocml/ns/akn/3.0}"
    coverPage = tree.find(".//"+akn+"coverPage")
    preamble =  tree.find(".//"+akn+"preamble")
    mainBody = tree.find(".//"+akn+"mainBody")
    

    resolution_data = []

    #----------------------
    formula = preamble.find(".//"+akn+"formula")
    if(isinstance(formula, ET.Element)):
        formula = formula.find(".//"+akn+"span").text
    else:
        formula = ''
    #----------------------

    containers = preamble.findall(".//"+akn+"container")

    for c in containers:
        preamble_text = c.find(".//"+akn+"p")

        if preamble_text:

            d = get_coverPage_data(akn, coverPage)
            d['forumula'] = formula
            d['eId'] = c.attrib['eId']
            d['p_num'] = ''
            d['text'] = md(ET.tostring(preamble_text, encoding='utf8', method='xml').decode("utf8")).replace("xml version='1.0' encoding='utf8'?","").strip()
            resolution_data.append(d)


    paragraphs = mainBody.findall(".//"+akn+"paragraph")

    for p in paragraphs:
        p_num = p.find(".//"+akn+"num")
        if(isinstance(p_num, ET.Element)):
            p_num = p_num.text
        else: 
            p_num = ''

        p_heading = p.findall(".//"+akn+"heading")
        if p_heading:
            for ph in p_heading:

                d = get_coverPage_data(akn, coverPage)
                d['forumula'] = formula
                d['eId'] = p.attrib['eId']
                d['p_num'] = p_num
                d['text'] = md(ET.tostring(ph, encoding='utf8', method='xml').decode("utf8")).replace("xml version='1.0' encoding='utf8'?","").strip()
                resolution_data.append(d)

        p_content = p.findall(".//"+akn+"content")
        if p_content:
            for pc in p_content:

                d = get_coverPage_data(akn, coverPage)
                d['forumula'] = formula
                d['eId'] = p.attrib['eId']
                d['p_num'] = p_num
                d['text'] = md(ET.tostring(pc, encoding='utf8', method='xml').decode("utf8")).replace("xml version='1.0' encoding='utf8'?","").strip()
                resolution_data.append(d)
                
    x = pd.DataFrame(resolution_data)
    x['select'] = False
    
    for index, row in x.iterrows():
        for k in keywords:
            if k in row['text']:
                row['select'] = True
        
    return x

# %%
def get_ga_data(path, keywords):
    data = []
    ga_files = os_sorted(os.listdir(path))
    for idx, file in enumerate(ga_files):
        data.append(get_resolution_data(path,file, keywords))
    return pd.concat(data)

# %%
GA_76_path = "../UNxml/GAresolutions-main/76session/English/"
GA_77_path = "../UNxml/GAresolutions-main/77session/English/"
ECOSOC_2021_path = "../UNxml/ECOSOCresolutions-main/2021/English/"
ECOSOC_2021_path = "../UNxml/ECOSOCresolutions-main/2022/English/"

# %%
ga_76_data = get_ga_data(GA_76_path,['statistic', 'data'])
# ga_77_data = get_ga_data(GA_77_path)
# ecosoc_2021_data = get_ga_data(ECOSOC_2021_path)
# ecosoc_2022_data = get_ga_data(ECOSOC_2022_path)

# %%
ga_76_data.to_excel("../test.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 ga_76_data.to_excel("../test.xlsx")
#
# File ~\Projects\GA-ECOSOC\ga-ecosoc-venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Projects\GA-ECOSOC\ga-ecosoc-venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Projects\GA-ECOSOC\ga-ecosoc-venv\lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\Projects\GA-ECOSOC\ga-ecosoc-venv\lib\site-packages\pandas\io\formats\excel.py:918, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     914     need_save = False
#     915 else:
#     916     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     917     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 918     writer = ExcelWriter(  # type: ignore[abstract]
#     919         writer, engine=engine, storage_options=storage_options
#     920     )
#     921     need_save = True
#     923 try:
#
# File ~\Projects\GA-ECOSOC\ga-ecosoc-venv\lib\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
# Out:
#           publisher       issuingBody        symbol        docStatus  \
# 11   United Nations  General Assembly   A/RES/76/16  Distr.: General
# 151  United Nations  General Assembly   A/RES/76/71  Distr.: General
# 8    United Nations  General Assembly   A/RES/76/85  Distr.: General
# 16   United Nations  General Assembly  A/RES/76/135  Distr.: General
# 60   United Nations  General Assembly  A/RES/76/136  Distr.: General
# 43   United Nations  General Assembly  A/RES/76/137  Distr.: General
# 48   United Nations  General Assembly  A/RES/76/138  Distr.: General
# 52   United Nations  General Assembly  A/RES/76/140  Distr.: General
# 53   United Nations  General Assembly  A/RES/76/140  Distr.: General
# 37   United Nations  General Assembly  A/RES/76/141  Distr.: General
# 53   United Nations  General Assembly  A/RES/76/142  Distr.: General
# 68   United Nations  General Assembly  A/RES/76/142  Distr.: General
# 13   United Nations  General Assembly  A/RES/76/146  Distr.: General
# 55   Globalization and interdependence: development...
# 42   Groups of countries in special situations: fol...
# 32   Eradication of poverty and other development i...
# 52   Eradication of poverty and other development i...
# 29   Eradication of poverty and other development i...
# 11   Scale of assessments for the apportionment of ...
# 14   Scale of assessments for the apportionment of ...
# 21   Scale of assessments for the apportionment of ...
# 15   Scale of assessments for the apportionment of ...
# 10                                Advancement of women
# 68   Administrative and budgetary aspects of the fi...
# 31   New Partnership for Africa’s Development: prog...
#
#                                               docTitle               forumula  \
# 11   Resolution adopted by the General Assembly on ...   The General Assembly
# 151  Resolution adopted by the General Assembly on ...   The General Assembly
# 8    Resolution adopted by the General Assembly on ...   The General Assembly
# 16   Resolution adopted by the General Assembly on ...   The General Assembly
# 60   Resolution adopted by the General Assembly on ...   The General Assembly
# 43   Resolution adopted by the General Assembly on ...   The General Assembly
# 48   Resolution adopted by the General Assembly on ...   The General Assembly
# 52   Resolution adopted by the General Assembly on ...   The General Assembly
# 53   Resolution adopted by the General Assembly on ...   The General Assembly
# 37   Resolution adopted by the General Assembly on ...  The General Assembly,
# 53   Resolution adopted by the General Assembly on ...   The General Assembly
# 68   Resolution adopted by the General Assembly on ...   The General Assembly
# 13   Resolution adopted by the General Assembly on ...   The General Assembly
# 57   Resolution adopted by the General Assembly on ...   The General Assembly
# 69   Resolution adopted by the General Assembly on ...   The General Assembly
# 97   Resolution adopted by the General Assembly on ...   The General Assembly
# 54   Resolution adopted by the General Assembly on ...   The General Assembly
# 35   Resolution adopted by the General Assembly on ...   The General Assembly
# 66   Resolution adopted by the General Assembly on ...   The General Assembly
# 81   Resolution adopted by the General Assembly on ...   The General Assembly
# 81   Resolution adopted by the General Assembly on ...   The General Assembly
# 99   Resolution adopted by the General Assembly on ...   The General Assembly
# 36   Resolution adopted by the General Assembly on ...   The General Assembly
# 21   Resolution adopted by the General Assembly on ...   The General Assembly
# 129  Resolution adopted by the General Assembly on ...   The General Assembly
# 139  Resolution adopted by the General Assembly on ...   The General Assembly
# 146  Resolution adopted by the General Assembly on ...   The General Assembly
# 126  Resolution adopted by the General Assembly on ...   The General Assembly
# 128  Resolution adopted by the General Assembly on ...   The General Assembly
# 132  Resolution adopted by the General Assembly on ...   The General Assembly
# 29   Resolution adopted by the General Assembly on ...   The General Assembly
# 32   Resolution adopted by the General Assembly on ...   The General Assembly
# 47   Resolution adopted by the General Assembly on ...   The General Assembly
# 60   Resolution adopted by the General Assembly on ...   The General Assembly
# 29   Resolution adopted by the General Assembly on ...   The General Assembly
# 8    Resolution adopted by the General Assembly on ...   The General Assembly
# 35   Resolution adopted by the General Assembly on ...   The General Assembly
# 47   Resolution adopted by the General Assembly on ...   The General Assembly
# 60   Resolution adopted by the General Assembly on ...   The General Assembly
# 66   Resolution adopted by the General Assembly on ...   The General Assembly
# 55   Resolution adopted by the General Assembly on ...   The General Assembly
# 42   Resolution adopted by the General Assembly on ...   The General Assembly
# 32   Resolution adopted by the General Assembly on ...   The General Assembly
# 52   Resolution adopted by the General Assembly on ...   The General Assembly
# 29   Resolution adopted by the General Assembly on ...   The General Assembly
# 11   Resolution adopted by the General Assembly on ...   The General Assembly
# 14   Resolution adopted by the General Assembly on ...   The General Assembly
# 21   Resolution adopted by the General Assembly on ...   The General Assembly
# 15   Resolution adopted by the General Assembly on ...   The General Assembly
# 10   Resolution adopted by the General Assembly on ...   The General Assembly
# 68   Resolution adopted by the General Assembly on ...   The General Assembly
# 31   Resolution adopted by the General Assembly on ...   The General Assembly
#
#               eId p_num                                               text
# 11   container_13        Recalling also the Doha Declaration on Integra...
# 151     para_1288   69.  Also reaffirms its request that the Food and A...
# 8         para_11    3.  Also requests the administering Powers concern...
# 16        para_46    9.  Also encourages Governments to intensify and e...
# 60       para_293   23.  Encourages Member States to improve the collec...
# 43        para_73    9.  Stresses the need to strengthen and support th...
# 48       para_326   25.  Recommends that Member States enhance their ca...
# 52        para_20    2.  Addressing the lack of quality, accessible, ti...
# 53        para_20    2.  Strengthening the capacity of national statist...
# 37   container_39        Emphasizing the need for objective, comprehens...
# 53       para_168   17.  Closing data and evidence gaps through improve...
# 68       para_497   31.  Encourages Member States, with the support of,...
# 13   container_15        Deeply concerned also about the continuing lac...
# 57       para_410   28.  Calls upon States to strengthen research, data...
# 69       para_397   30.  Recognizes that the right of the child to educ...
# 97       para_404   32.  Improving and securing a comprehensive approac...
# 54       para_617   35.  Underlines the importance of reliable disaggre...
# 35   container_37        Concerned that the continuing lack of availabl...
# 66       para_503   31.  To ensure that international cooperation is ge...
# 81       para_863   41.  Encourages Member States, members of the Inter...
# 81        para_92   11.  Calls upon the United Nations system and other...
# 99       para_125   12.  Calls upon all international organizations and...
# 36        para_93   12.  Strongly encourages Member States, in accordan...
# 21   container_23        Taking note of the United Nations Office on Dr...
# 129     para_1616   56.  Encourages States parties to the United Nation...
# 139     para_2221   66.  Requests the United Nations Office on Drugs an...
# 146     para_2704   73.  Reiterates its invitation to Member States to ...
# 126     para_3782   87.  Requests the United Nations Office on Drugs an...
# 128     para_3957   89.  Recalls Statistical Commission decision 48/110...
# 132     para_4319   93.  Reiterates the commitment of Member States to ...
# 29        para_52    8.  Reiterates that debtors and creditors, includi...
# 32        para_55    8.  Also reiterates that timely and comprehensive ...
# 47       para_280   23.  Reiterates that debtors and creditors must wor...
# 60       para_657   36.  Invites the United Nations Conference on Trade...
# 29   container_31        Stressing the need to support and strengthen i...
# 8    container_10        Recalling its resolution 70/193 of 22 December...
# 35       para_245   22.  Recognizes that improved data collection and s...
# 47       para_220   20.  Recognizes that disaster risk reduction requir...
# 60       para_233   20.  Encourages enhanced capacity-building support ...
# 66       para_283   23.  Invites the United Nations Educational, Scient...
# 55       para_228   20.  Recognizes that Governments will have the prim...
# 42       para_320   25.  Decides, in accordance with paragraph 66 of th...
# 32        para_34    2.  Recognizes the importance of strengthening nat...
# 52       para_264   22.  Stresses the importance of using multidimensio...
# 29        para_46    7.  Stresses the importance of taking targeted mea...
# 11        para_27    7.  Average statistical base periods of three and ...
# 14        para_27    7.  A low per capita income adjustment of 80 per c...
# 21        para_61   11.  Supports the efforts of the Statistics Divisio...
# 15        para_34    8.  Further reaffirms that the statistical data us...
# 10   container_12        Noting with regret the absence of high-quality...
# 68       para_483   62.  Encourages the Secretary-General to continue t...
# 31        para_88   12.  Reiterates the need to support African countri...

